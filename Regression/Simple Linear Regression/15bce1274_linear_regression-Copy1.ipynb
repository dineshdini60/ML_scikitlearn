# %%
import pandas as pd

# %%
sdd = pd.read_csv('trim_poke.csv')

# %%
#df.columns = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD','TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
sdd.head()
# Out:
#    Number        Name Type_1  Total  HP  Attack  Defense  Sp_Atk  Sp_Def  \
# 0       1   Bulbasaur  Grass    318  45      49       49      65      65
# 1       2     Ivysaur  Grass    405  60      62       63      80      80
# 2       3    Venusaur  Grass    525  80      82       83     100     100
# 3       4  Charmander   Fire    309  39      52       43      60      50
# 4       5  Charmeleon   Fire    405  58      64       58      80      65
#
#    Speed  Height_m  Weight_kg
# 0     45      0.71        6.9
# 1     60      0.99       13.0
# 2     80      2.01      100.0
# 3     65      0.61        8.5
# 4     80      1.09       19.0

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.set(style='whitegrid', context='notebook')

# %%
cols = ['HP', 'Attack', 'Defense', 'Height_m','Weight_kg']

# %%
sns.pairplot(sdd[cols], size=2.5);

# %%
plt.show()

# %%
import numpy as np

# %%
cm = np.corrcoef(sdd[cols].values.T)

# %%
sns.set(font_scale=1.5)

# %%
hm = sns.heatmap(cm,cbar=True,annot=True,square=True,fmt='.2f',annot_kws={'size': 15},yticklabels=cols,xticklabels=cols)

# %%
plt.show()

# %%
class LinearRegressionGD(object):
    def __init__(self, eta=0.001, n_iter=200):
        self.eta = eta
        self.n_iter = n_iter
    def fit(self, X, y):
        self.w_ = np.zeros(1 + X.shape[1])
        self.cost_ = []
        for i in range(self.n_iter):
            output = self.net_input(X)
            errors = (y - output)
            self.w_[1:] += self.eta * X.T.dot(errors)
            self.w_[0] += self.eta * errors.sum()
            cost = (errors**2).sum() / 2.0
            self.cost_.append(cost)
        return self
    def net_input(self, X):
           return np.dot(X, self.w_[1:]) + self.w_[0]
    def predict(self, X):
           return self.net_input(X)

# %%
X = sdd[['HP']].values

# %%
X1 = sdd[['Height_m']].values

# %%
y = sdd['Attack'].values

# %%
y1 = sdd['Weight_kg'].values

# %%
y
# Out:
# array([ 49,  62,  82,  52,  64,  84,  48,  63,  83,  30,  20,  45,  35,
#         25,  90,  45,  60,  80,  56,  81,  60,  90,  60,  85,  55,  90,
#         75, 100,  47,  62,  92,  57,  72, 102,  45,  70,  41,  76,  45,
#         70,  45,  80,  50,  65,  80,  70,  95,  55,  65,  55,  80,  45,
#         70,  52,  82,  80, 105,  70, 110,  50,  65,  95,  20,  35,  50,
#         80, 100, 130,  75,  90, 105,  40,  70,  80,  95, 120,  85, 100,
#         65,  75,  35,  60,  65,  85, 110,  45,  70,  80, 105,  65,  95,
#         35,  50,  65,  45,  48,  73, 105, 130,  30,  50,  40,  95,  50,
#         80, 120, 105,  55,  65,  90,  85, 130,   5,  55,  95,  40,  65,
#         67,  92,  45,  75,  45, 110,  50,  83,  95, 125, 100,  10, 125,
#         85,  48,  55,  65,  65, 130,  60,  40,  60,  80, 115, 105, 110,
#         85,  90, 100,  64,  84, 134, 110, 100,  49,  62,  82,  52,  64,
#         84,  65,  80, 105,  46,  76,  30,  50,  20,  35,  60,  90,  90,
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc_x = StandardScaler()

# %%
sc_x1 = StandardScaler()

# %%
sc_x
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
sc_x1
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
sc_y = StandardScaler()

# %%
sc_y1 = StandardScaler()

# %%
X_std = sc_x.fit_transform(X)
# Out:
# C:\Users\chall\Anaconda3\lib\site-packages\sklearn\utils\validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)

# %%
X_std1 = sc_x.fit_transform(X1)

# %%
X_std
# Out:
# array([[-0.9051382 ],
#        [-0.32442576],
#        [ 0.4498575 ],
#        [-1.13742318],
#        [-0.40185408],
#        [ 0.37242917],
#        [-0.94385236],
#        [-0.36313992],
#        [ 0.41114334],
#        [-0.9051382 ],
#        [-0.71156739],
#        [-0.32442576],
#        [-1.09870901],
#        [-0.9051382 ],
#        [-0.13085494],
#        [-1.09870901],
#        [-0.20828327],
#        [ 0.56599999],
#        [-1.48585064],
#        [-0.51799657],
#        [-1.09870901],
#        [-0.13085494],
#        [-1.29227983],
#        [-0.32442576],
#        [-1.29227983],
#        [-0.32442576],
#        [-0.71156739],
#        [ 0.25628668],
#        [-0.51799657],
#        [ 0.06271587],
#        [ 0.83699913],
#        [-0.86642404],
#        [-0.2857116 ],
#        [ 0.48857166],
#        [ 0.06271587],
#        [ 1.03056994],
#        [-1.17613734],
#        [ 0.17885836],
#        [ 1.8048532 ],
#        [ 2.77270727],
#        [-1.09870901],
# ...

# %%
X_std1
# Out:
# array([[ -0.41678886],
#        [ -0.14849814],
#        [  0.82884661],
#        [ -0.51260697],
#        [ -0.05268003],
#        [  0.53181046],
#        [ -0.60842508],
#        [ -0.14849814],
#        [  0.43599235],
#        [ -0.80964312],
#        [ -0.41678886],
#        [ -0.05268003],
#        [ -0.80964312],
#        [ -0.51260697],
#        [ -0.14849814],
#        [ -0.80964312],
#        [ -0.05268003],
#        [  0.34017424],
#        [ -0.80964312],
#        [ -0.41678886],
#        [ -0.80964312],
#        [  0.04313809],
#        [  0.82884661],
#        [  2.26611831],
#        [ -0.7042432 ],
#        [ -0.34013437],
#        [ -0.51260697],
#        [ -0.14849814],
#        [ -0.7042432 ],
#        [ -0.34013437],
#        [  0.14853801],
#        [ -0.60842508],
#        [ -0.24431625],
#        [  0.24435612],
#        [ -0.51260697],
#        [  0.14853801],
#        [ -0.51260697],
#        [ -0.05268003],
#        [ -0.60842508],
#        [ -0.14849814],
# ...

# %%
y_std = sc_y.fit_transform(y)
# Out:
# C:\Users\chall\Anaconda3\lib\site-packages\sklearn\utils\validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)
# C:\Users\chall\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# C:\Users\chall\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %%
y_std1 = sc_y.fit_transform(y1)
# Out:
# C:\Users\chall\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# C:\Users\chall\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %%
y_std
# Out:
# array([ -8.98133511e-01,  -4.49306181e-01,   2.41197403e-01,
#         -7.94557973e-01,  -3.80255823e-01,   3.10247762e-01,
#         -9.32658690e-01,  -4.14781002e-01,   2.75722582e-01,
#         -1.55411192e+00,  -1.89936371e+00,  -1.03623423e+00,
#         -1.38148602e+00,  -1.72673781e+00,   5.17398837e-01,
#         -1.03623423e+00,  -5.18356539e-01,   1.72147045e-01,
#         -6.56457256e-01,   2.06672224e-01,  -5.18356539e-01,
#          5.17398837e-01,  -5.18356539e-01,   3.44772941e-01,
#         -6.90982436e-01,   5.17398837e-01,  -4.78851307e-04,
#          8.62650629e-01,  -9.67183869e-01,  -4.49306181e-01,
#          5.86449195e-01,  -6.21932077e-01,  -1.04054389e-01,
#          9.31700987e-01,  -1.03623423e+00,  -1.73104747e-01,
#         -1.17433494e+00,   3.40463279e-02,  -1.03623423e+00,
#         -1.73104747e-01,  -1.03623423e+00,   1.72147045e-01,
#         -8.63608332e-01,  -3.45730643e-01,   1.72147045e-01,
# ...

# %%
y_std1
# Out:
# array([ -5.60161839e-01,  -4.91648579e-01,   4.85507762e-01,
#         -5.42191148e-01,  -4.24258486e-01,   3.78806782e-01,
#         -5.36575307e-01,  -3.84947599e-01,   3.22648372e-01,
#         -6.05088567e-01,  -5.26466793e-01,  -2.78246619e-01,
#         -6.01719063e-01,  -5.25343625e-01,  -3.06325824e-01,
#         -6.17443418e-01,  -3.00709983e-01,  -1.94009004e-01,
#         -5.98349558e-01,  -4.29874327e-01,  -6.15197081e-01,
#         -2.10856527e-01,  -5.60161839e-01,   9.23988891e-02,
#         -5.70270353e-01,  -3.00709983e-01,  -5.02880261e-01,
#         -3.06325824e-01,  -5.59038671e-01,  -4.13026804e-01,
#          3.62404787e-02,  -5.36575307e-01,  -4.18642645e-01,
#          5.87038429e-02,  -5.53422830e-01,  -1.88393163e-01,
#         -5.26466793e-01,  -4.14149972e-01,  -5.75886194e-01,
#         -5.02880261e-01,  -5.53422830e-01,  -1.99179316e-02,
#         -5.77009362e-01,  -5.41067980e-01,  -4.28751159e-01,
# ...

# %%
lr = LinearRegressionGD()

# %%
lr1 = LinearRegressionGD()

# %%
lr.fit(X_std, y_std)

# %%
lr1.fit(X_std, y_std)

# %%
plt.plot(range(1, lr.n_iter+1), lr.cost_)

# %%
plt.ylabel('SSE')

# %%
plt.xlabel('Epoch')

# %%
#sse = sum of squared errors
plt.show()

# %%
plt.plot(range(1, lr1.n_iter+1), lr1.cost_)
plt.ylabel('SSE')
plt.xlabel('Epoch')
plt.show()

# %%
def lin_regplot(X, y, model):
    plt.scatter(X, y, c='blue')
    plt.plot(X, model.predict(X), color='red')
    return None

# %%
def lin_regplot1(X1, y1, model):
    plt.scatter(X1, y1, c='blue')
    plt.plot(X1, model.predict(X1), color='red')
    return None

# %%
lin_regplot(X_std, y_std, lr)

# %%
lin_regplot1(X_std1, y_std1, lr1)

# %%
plt.xlabel('HP')

# %%
plt.ylabel('Attack')

# %%
plt.show()

# %%
plt.ylabel('weight')
plt.xlabel('height')
plt.show()
